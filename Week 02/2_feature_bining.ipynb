# %% [markdown]
# #### 1.Import Dependencies

# %% [markdown]
# How Binning Helps?
# 1. Non-linear relationship with target
# - Bining can help cature non-linear patterns that a linear model might miss
#
# 2. Skewed distribution
# - Binning can smooth out skew and reduce the effect of extreme values
#
# 3. Interpretability is the key
# - Easier for business users to understand "age 18-25" than "age=23"
#
# 4. Model is prone to overfitting
# - Binning reduces granularity -> fewer splits -> less overfitting
#
# 5. Need to reduce cardinality
# - Helps when a numeric column has too many unique values
#
# 6. Sparse or noisy data
# - Binning can group rare or noisy values to improve signal strength

# %%
import os
import pandas as pd 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### 2. Basic Processing

# %%
df = pd.read_csv("../Week 01/Data/processed/churnModelling_outliers_handled.csv")
df.head(5)
# Out:
#    Unnamed: 0  CreditScore Geography  Gender    Age  Tenure    Balance  \
# 0           0          619    France       0  42.00       2       0.00
# 1           1          608     Spain       0  41.00       1   83807.86
# 2           2          502    France       0  42.00       8  159660.80
# 3           3          699    France       0  38.91       1       0.00
# 4           4          850     Spain       0  43.00       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0

# %%
df['Age'].min(),df['Age'].max()
# Out:
# (np.float64(18.0), np.float64(92.0))

# %% [markdown]
# Before feature binning you have to have a good understanding of lower-bound and upper-bound. If you uncertain about it don't go for it

# %% [markdown]
# 350 - 580 => 'Poor'
# 580 - 670 => 'Fair'
# 670 - 740 => 'Good'
# 740 - 800 => 'Very Good'
# 800 - 850 => 'Excellent'

# %%
def custom_binning_credit_score(score):
    if score < 580:
        return 'Poor'
    elif score < 670:
        return 'Fair'
    elif score < 740:
        return 'Good'
    elif score < 800:
        return 'Very Good' 
    elif score <= 850:
        return 'Excellent'
    else:
        assert True, "Credit Score can't go higher than 850"

df['CreditScoreBins'] = df['CreditScore'].apply(custom_binning_credit_score)
del df['CreditScore']

df.head(10)
# Out:
#    Unnamed: 0 Geography  Gender    Age  Tenure    Balance  NumOfProducts  \
# 0           0    France       0  42.00       2       0.00              1
# 1           1     Spain       0  41.00       1   83807.86              1
# 2           2    France       0  42.00       8  159660.80              3
# 3           3    France       0  38.91       1       0.00              2
# 4           4     Spain       0  43.00       2  125510.82              1
# 5           5     Spain       1  44.00       8  113755.78              2
# 6           6    France       1  50.00       7       0.00              2
# 7           7   Germany       0  29.00       4  115046.74              4
# 8           8    France       1  44.00       4  142051.07              2
# 9           9    France       1  27.00       2  134603.88              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited CreditScoreBins
# 0          1               1        101348.88       1            Fair
# 1          0               1        112542.58       0            Fair
# 2          1               0        113931.57       1            Poor
# 3          0               0         93826.63       0            Good
# 4          1               1         79084.10       0       Excellent
# 5          1               0        149756.71       1            Fair
# 6          1               1         10062.80       0       Excellent
# 7          1               0        119346.88       1            Poor
# 8          0               1         74940.50       0            Poor
# 9          1               1         71725.73       0            Good

# %%
df['Gender'] = df['Gender'].apply(lambda x:"Male" if x==1 else "Female")
df
# Out:
#       Unnamed: 0 Geography  Gender    Age  Tenure    Balance  NumOfProducts  \
# 0              0    France  Female  42.00       2       0.00              1
# 1              1     Spain  Female  41.00       1   83807.86              1
# 2              2    France  Female  42.00       8  159660.80              3
# 3              3    France  Female  38.91       1       0.00              2
# 4              4     Spain  Female  43.00       2  125510.82              1
# ...          ...       ...     ...    ...     ...        ...            ...
# 9995        9995    France  Female  39.00       5       0.00              2
# 9996        9996    France  Female  35.00      10   57369.61              1
# 9997        9997    France  Female  36.00       7       0.00              1
# 9998        9998   Germany  Female  42.00       3   75075.31              2
# 9999        9999    France  Female  28.00       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited CreditScoreBins
# 0             1               1        101348.88       1            Fair
# 1             0               1        112542.58       0            Fair
# 2             1               0        113931.57       1            Poor
# 3             0               0         93826.63       0            Good
# 4             1               1         79084.10       0       Excellent
# ...         ...             ...              ...     ...             ...
# 9995          1               0         96270.64       0       Very Good
# 9996          1               1        101699.77       0            Poor
# 9997          0               1         42085.58       1            Good
# 9998          1               0         92888.52       1       Very Good
# 9999          1               0         38190.78       0       Very Good
#
# [10000 rows x 12 columns]

# %%
df.to_csv("../Week 01/Data/processed/churnModelling_binning_applied.csv")
